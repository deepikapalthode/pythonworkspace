# %%
import pandas as pd
pop = pd.read_csv("/home/siddhan/python_deepika/data-USstates-master/state-population.csv")

# %%
states = pd.read_csv("/home/siddhan/python_deepika/data-USstates-master/state-areas.csv")
abbr = pd.read_csv("/home/siddhan/python_deepika/data-USstates-master/state-abbrevs.csv")

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
states.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abbr.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
m1 = pd.merge(pop,abbr, left_on = "state/region",right_on = "abbreviation", how = "outer")

# %%
m1.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# abbreviation     True
# dtype: bool

# %%
m1.head()
# Out:
#   state/region     ages  year  population    state abbreviation
# 0           AL  under18  2012   1117489.0  Alabama           AL
# 1           AL    total  2012   4817528.0  Alabama           AL
# 2           AL  under18  2010   1130966.0  Alabama           AL
# 3           AL    total  2010   4785570.0  Alabama           AL
# 4           AL  under18  2011   1125763.0  Alabama           AL

# %%
m1.drop("abbreviation",axis="columns",inplace= True)

# %%
m1.head()
# Out:
#   state/region     ages  year  population    state
# 0           AL  under18  2012   1117489.0  Alabama
# 1           AL    total  2012   4817528.0  Alabama
# 2           AL  under18  2010   1130966.0  Alabama
# 3           AL    total  2010   4785570.0  Alabama
# 4           AL  under18  2011   1125763.0  Alabama

# %%
states.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
data = pd.merge(m1,states,left_on = "state",right_on = "state",how = "outer")

# %%
data.head()
# Out:
#   state/region     ages    year  population    state  area (sq. mi)
# 0           AL  under18  2012.0   1117489.0  Alabama        52423.0
# 1           AL    total  2012.0   4817528.0  Alabama        52423.0
# 2           AL  under18  2010.0   1130966.0  Alabama        52423.0
# 3           AL    total  2010.0   4785570.0  Alabama        52423.0
# 4           AL  under18  2011.0   1125763.0  Alabama        52423.0

# %%
data.isnull().any()
# Out:
# state/region     True
# ages             True
# year             True
# population       True
# state            True
# area (sq. mi)    True
# dtype: bool

# %%
data.isnull().any()
# Out:
# state/region     True
# ages             True
# year             True
# population       True
# state            True
# area (sq. mi)    True
# dtype: bool

# %%
data.rename(columns={"state/region":"code"},inplace=True)

# %%
data.rename(columns={"area (sq. mi)":"area"},inplace=True)

# %%
data.columns
# Out:
# Index(['code', 'ages', 'year', 'population', 'state', 'area'], dtype='object')

# %%
data.shape
# Out:
# (2545, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2545 entries, 0 to 2544
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        2544 non-null   object
#  1   ages        2544 non-null   object
#  2   year        2544 non-null   float64
#  3   population  2524 non-null   float64
#  4   state       2449 non-null   object
#  5   area        2449 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 139.2+ KB

# %%
data.isnull().any()
# Out:
# code          True
# ages          True
# year          True
# population    True
# state         True
# area          True
# dtype: bool

# %%
data[data["code"].isnull()]
# Out:
#      code ages  year  population        state    area
# 2544  NaN  NaN   NaN         NaN  Puerto Rico  3515.0

# %%
m1.head()
# Out:
#   state/region     ages  year  population    state
# 0           AL  under18  2012   1117489.0  Alabama
# 1           AL    total  2012   4817528.0  Alabama
# 2           AL  under18  2010   1130966.0  Alabama
# 3           AL    total  2010   4785570.0  Alabama
# 4           AL  under18  2011   1125763.0  Alabama

# %%
usa = m1

# %%
usa.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# dtype: bool

# %%
usa[usa["state"].isnull()].head()
# Out:
#      state/region     ages  year  population state
# 2448           PR  under18  1990         NaN   NaN
# 2449           PR    total  1990         NaN   NaN
# 2450           PR    total  1991         NaN   NaN
# 2451           PR  under18  1991         NaN   NaN
# 2452           PR    total  1993         NaN   NaN

# %%
usa.rename(columns={"state/region":"code"},inplace=True)

# %%
usa.columns
# Out:
# Index(['code', 'ages', 'year', 'population', 'state'], dtype='object')

# %%
usa.loc[usa["state"].isnull()]["code"].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
usa["code"]=="USA"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2539     True
# 2540     True
# 2541     True
# 2542     True
# 2543     True
# Name: code, Length: 2544, dtype: bool

# %%
usa.loc[usa["state"].isnull(),"code"].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
usa[usa["state"].isnull()].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2445/849925712.py in <module>
# ----> 1 usa[usa["state"].isnull()].unique()
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
pd.unique(pd.Series([2, 1, 3, 3]))
# Out:
# array([2, 1, 3])

# %%
usa["state"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', nan], dtype=object)

# %%
usa[usa["state"].isnull()].nunique()
# Out:
# code           2
# ages           2
# year          24
# population    76
# state          0
# dtype: int64

# %%
usa.loc[usa["state"].isnull(),"code"].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
usa[usa["population"].isnull()].head()
# Out:
#      code     ages  year  population        state
# 2448   PR  under18  1990         NaN  Puerto Rico
# 2449   PR    total  1990         NaN  Puerto Rico
# 2450   PR    total  1991         NaN  Puerto Rico
# 2451   PR  under18  1991         NaN  Puerto Rico
# 2452   PR    total  1993         NaN  Puerto Rico

# %%
usa.loc[usa["state"].isnull(),"code"].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
usa.loc[usa["code"]=="PR","state"] = "Puerto Rico"

# %%
usa.loc[usa["code"]=="USA","state"] = "United States"

# %%
usa.isnull().any()
# Out:
# code          False
# ages          False
# year          False
# population     True
# state          True
# dtype: bool

# %%
usa.loc[usa["population"].isnull(),"state"].unique()
# Out:
# array(['Puerto Rico'], dtype=object)

# %%
usa[usa["state"].isnull()]
# Out:
# Empty DataFrame
# Columns: [code, ages, year, population, state]
# Index: []

# %%
usa.loc[usa["code"]=="PR","state"] = "Port Rico"

# %%
usa.loc[usa["code"]=="PR"].head()
# Out:
#      code     ages  year  population      state
# 2448   PR  under18  1990         NaN  Port Rico
# 2449   PR    total  1990         NaN  Port Rico
# 2450   PR    total  1991         NaN  Port Rico
# 2451   PR  under18  1991         NaN  Port Rico
# 2452   PR    total  1993         NaN  Port Rico

# %%
states["Puerto Rico"] = "Port Rico"

# %%
final = pd.merge(usa,states,on="state",how="outer")

# %%
final.head()
# Out:
#   code     ages  year  population    state  area (sq. mi)
# 0   AL  under18  2012   1117489.0  Alabama        52423.0
# 1   AL    total  2012   4817528.0  Alabama        52423.0
# 2   AL  under18  2010   1130966.0  Alabama        52423.0
# 3   AL    total  2010   4785570.0  Alabama        52423.0
# 4   AL  under18  2011   1125763.0  Alabama        52423.0

# %%
final.isnull().any()
# Out:
# code             False
# ages             False
# year             False
# population        True
# state            False
# area (sq. mi)     True
# dtype: bool

# %%
states.drop("Puerto Rico",axis = "columns",inplace=True)

# %%
states.loc[states.state=="Puerto Rico","state"] = "Port Rico"

# %%
states
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
states
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
# import numexpr package
final.query("year == 2010 & ages == 'total'")
# Out:
#      code   ages  year   population                 state  area (sq. mi)
# 3      AL  total  2010    4785570.0               Alabama        52423.0
# 91     AK  total  2010     713868.0                Alaska       656425.0
# 101    AZ  total  2010    6408790.0               Arizona       114006.0
# 189    AR  total  2010    2922280.0              Arkansas        53182.0
# 197    CA  total  2010   37333601.0            California       163707.0
# 283    CO  total  2010    5048196.0              Colorado       104100.0
# 293    CT  total  2010    3579210.0           Connecticut         5544.0
# 379    DE  total  2010     899711.0              Delaware         1954.0
# 389    DC  total  2010     605125.0  District of Columbia           68.0
# 475    FL  total  2010   18846054.0               Florida        65758.0
# 485    GA  total  2010    9713248.0               Georgia        59441.0
# 570    HI  total  2010    1363731.0                Hawaii        10932.0
# ...

# %%
final.dropna(inplace = True)

# %%
final.shape
# Out:
# (2476, 6)

# %%
final.tail()
# Out:
#      code     ages  year  population      state  area (sq. mi)
# 2491   PR  under18  2010    896945.0  Port Rico         4500.0
# 2492   PR  under18  2011    869327.0  Port Rico         4500.0
# 2493   PR    total  2011   3686580.0  Port Rico         4500.0
# 2494   PR  under18  2012    841740.0  Port Rico         4500.0
# 2495   PR    total  2012   3651545.0  Port Rico         4500.0
